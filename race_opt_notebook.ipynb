# %%
from database_operations import DatabaseOperations
from overtake_model import OvertakingModel
from race_data import RaceDataSetup
from race_dataframe import RaceDataframe
from race_sim import RaceSimulation
from evaluation import RaceSimEvaluation, EvaluateMany
from optimisation import Optimisation

# %%
db = DatabaseOperations(2024, "Austin")
race_dataframe = RaceDataframe(db)
race_setup = RaceDataSetup(db, race_dataframe)
overtake = OvertakingModel(race_dataframe.race_df)
simulation = RaceSimulation(race_setup, overtake)
# Out:
# {np.int64(7): [22]}

# %%
simulation.simulate()
# Out:
# 1
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 simulation.simulate()
#
# File ~/Individual_Project/race_sim.py:77, in RaceSimulation.simulate(self)
#      73 """
#      74 Simulate the race and return the final drivers' data.
#      75 """
#      76 for lap in range(1, self.race_data.max_laps + 1):
# ---> 77 	self._process_lap(lap)
#      79 return self.sim_data
#
# File ~/Individual_Project/race_sim.py:98, in RaceSimulation._process_lap(self, lap)
#      96 # Process each sector
#      97 for sector in range(1, 4):
# ---> 98 	self._process_sector(sector, lap, safety_car)
#
# File ~/Individual_Project/race_sim.py:158, in RaceSimulation._process_sector(self, sector, lap, safety_car)
#     156 if sector == 1 and lap in d["pit_schedule"]:
#     157 	d["pit"] = True
# --> 158 	d["cumulative_time"] += self.race_data.driver_pit_times[d["driver_number"]]
#     159 	d["stint_lap"] = 1
#     160 	d["tyre_type"] = d["pit_schedule"][lap]
#
# KeyError: np.int64(22)

# %%
# optimiser = Optimisation(race_setup, overtake)
# driver = 16
# best_strategy, best_position = optimiser.bayesian_strategy_optimization(given_driver=driver, max_iterations=100)
# print(f"Best Strategy: {best_strategy}")
# print(f"Best Finishing Position: {best_position}")

# print(f"Actual Strategy: {race_setup.extract_driver_strategy(given_driver=driver)}")
# print(f"Actual finishing position: {race_setup.get_driver_finishing_position(given_driver=driver)}")
# Out:
# |   iter    |  target   | pit1_lap  | pit1_t... | pit2_lap  | pit2_t... | pit3_lap  | pit3_t... |
# -------------------------------------------------------------------------------------------------
# | 1         | -20.0     | 16.0      | 2.0       | 53.0      | 2.0       | 53.0      | 2.0       |
# Error during simulation: np.int64(22)
# | 2         | -20.0     | 20.73     | 1.901     | 38.6      | 1.197     | 9.801     | 0.312     |
# | 3         | -20.0     | 4.904     | 1.732     | 32.06     | 1.416     | 3.029     | 1.94      |
# Error during simulation: np.int64(22)
# | 4         | -20.0     | 43.62     | 0.4247    | 11.09     | 0.3668    | 17.21     | 1.05      |
# | 5         | -20.0     | 23.6      | 0.5825    | 32.59     | 0.279     | 16.61     | 0.7327    |
# Error during simulation: np.int64(22)
# | 6         | -20.0     | 24.8      | 1.57      | 11.98     | 1.028     | 31.62     | 0.0929    |
# | 7         | -20.0     | 50.15     | 0.6854    | 51.16     | 0.384     | 51.98     | 0.1518    |
# Error during simulation: np.int64(22)
# | 8         | -20.0     | 8.21      | 1.425     | 39.03     | 0.3128    | 33.69     | 1.77      |
# /home/ben/Individual_Project/env/lib/python3.10/site-packages/bayes_opt/target_space.py:421: UserWarning:
# Data point [16.  2. 53.  2. 53.  2.] is outside the bounds of the parameter space.
#   self.register(x, target)
# Error during simulation: np.int64(22)
# | 9         | -20.0     | 2.87      | 0.4525    | 3.221     | 1.893     | 51.78     | 1.751     |
# | 10        | -20.0     | 50.51     | 0.99      | 2.005     | 0.6266    | 3.214     | 0.09378   |
# | 11        | -20.0     | 51.13     | 1.046     | 3.87      | 1.907     | 51.56     | 1.426     |
# Error during simulation: np.int64(22)
# | 12        | -20.0     | 51.68     | 1.986     | 48.95     | 0.4426    | 3.148     | 1.603     |
# Error during simulation: np.int64(22)
# | 13        | -20.0     | 4.602     | 1.703     | 2.144     | 0.01988   | 2.082     | 1.506     |
# | 14        | -20.0     | 51.57     | 0.1913    | 51.53     | 0.7861    | 51.47     | 1.374     |
# | 15        | -20.0     | 2.174     | 0.7588    | 2.498     | 0.8087    | 51.55     | 0.2166    |
# | 16        | -20.0     | 2.964     | 0.782     | 51.2      | 0.1614    | 3.193     | 0.2888    |
# | 17        | -20.0     | 51.46     | 1.507     | 6.316     | 1.067     | 3.064     | 1.319     |
# | 18        | -20.0     | 51.42     | 0.7664    | 2.997     | 0.5716    | 51.95     | 0.8597    |
# | 19        | -20.0     | 2.257     | 1.759     | 51.62     | 1.056     | 51.86     | 0.04206   |
# Error during simulation: np.int64(22)
# | 20        | -20.0     | 3.315     | 1.073     | 51.69     | 0.5254    | 2.855     | 0.475     |
# | 21        | -20.0     | 51.66     | 1.529     | 51.07     | 1.474     | 2.525     | 0.1532    |
# Error during simulation: np.int64(22)
# | 22        | -20.0     | 3.406     | 1.118     | 2.606     | 0.4384    | 2.322     | 1.085     |
# Error during simulation: np.int64(22)
# | 23        | -20.0     | 2.374     | 1.918     | 50.76     | 0.07739   | 51.93     | 0.72      |
# Error during simulation: np.int64(22)
# | 24        | -20.0     | 3.043     | 0.01214   | 2.767     | 0.4331    | 51.35     | 1.992     |
# Error during simulation: np.int64(22)
# | 25        | -20.0     | 49.71     | 1.253     | 2.365     | 0.7495    | 51.0      | 1.76      |
# Error during simulation: np.int64(22)
# | 26        | -20.0     | 49.56     | 1.909     | 51.9      | 1.358     | 50.95     | 0.5646    |
# | 27        | -20.0     | 50.91     | 1.833     | 50.87     | 1.496     | 2.7       | 1.953     |
# Error during simulation: np.int64(22)
# | 28        | -20.0     | 3.189     | 0.9475    | 2.103     | 1.899     | 2.845     | 1.796     |
# Error during simulation: np.int64(22)
# | 29        | -20.0     | 49.82     | 1.526     | 3.149     | 1.949     | 2.579     | 0.1675    |
# Error during simulation: np.int64(22)
# | 30        | -20.0     | 3.565     | 0.7055    | 51.7      | 1.234     | 3.015     | 0.7005    |
# Error during simulation: np.int64(22)
# | 31        | -20.0     | 51.91     | 0.4901    | 51.59     | 1.482     | 49.38     | 0.2015    |
# Error during simulation: np.int64(22)
# | 32        | -20.0     | 5.042     | 1.094     | 2.654     | 0.3019    | 51.48     | 1.847     |
# | 33        | -20.0     | 51.58     | 1.19      | 2.277     | 1.519     | 2.731     | 1.054     |
# Error during simulation: np.int64(22)
# | 34        | -20.0     | 2.099     | 0.7468    | 51.24     | 1.488     | 2.364     | 0.8031    |
# Error during simulation: np.int64(22)
# | 35        | -20.0     | 2.034     | 0.593     | 2.848     | 1.152     | 51.93     | 0.3205    |
# Error during simulation: np.int64(22)
# | 36        | -20.0     | 51.85     | 1.129     | 3.156     | 0.2391    | 51.62     | 1.8       |
# Error during simulation: np.int64(22)
# | 37        | -20.0     | 51.35     | 0.4503    | 51.02     | 1.988     | 49.16     | 1.432     |
# Error during simulation: np.int64(22)
# | 38        | -20.0     | 3.195     | 0.4239    | 51.84     | 0.04561   | 2.638     | 1.134     |
# Error during simulation: np.int64(22)
# | 39        | -20.0     | 50.73     | 0.06733   | 2.463     | 1.99      | 3.642     | 0.2891    |
# Error during simulation: np.int64(22)
# | 40        | -20.0     | 3.617     | 0.6388    | 2.028     | 0.1965    | 50.13     | 1.439     |
# | 41        | -20.0     | 51.5      | 0.4985    | 50.76     | 0.8078    | 51.27     | 1.497     |
# | 42        | -20.0     | 2.135     | 0.3748    | 51.2      | 0.03902   | 2.688     | 0.993     |
# Error during simulation: np.int64(22)
# | 43        | -20.0     | 51.54     | 1.96      | 2.789     | 0.5656    | 3.846     | 0.2483    |
# Error during simulation: np.int64(22)
# | 44        | -20.0     | 2.383     | 0.7822    | 51.92     | 1.468     | 51.29     | 0.02205   |
# Error during simulation: np.int64(22)
# | 45        | -20.0     | 51.9      | 0.7595    | 51.51     | 1.726     | 5.26      | 1.942     |
# Error during simulation: np.int64(22)
# | 46        | -20.0     | 2.453     | 1.934     | 3.24      | 0.7069    | 2.547     | 0.7731    |
# Error during simulation: np.int64(22)
# | 47        | -20.0     | 3.919     | 0.2031    | 2.297     | 1.379     | 51.91     | 1.513     |
# Error during simulation: np.int64(22)
# | 48        | -20.0     | 51.72     | 1.894     | 2.73      | 1.068     | 3.444     | 0.06385   |
# Error during simulation: np.int64(22)
# | 49        | -20.0     | 51.95     | 0.5009    | 50.32     | 0.7685    | 48.94     | 1.706     |
# Error during simulation: np.int64(22)
# | 50        | -20.0     | 2.188     | 1.879     | 49.99     | 0.2573    | 51.95     | 0.4459    |
# Error during simulation: np.int64(22)
# | 51        | -20.0     | 3.313     | 1.374     | 2.024     | 0.9546    | 51.22     | 1.165     |
# Error during simulation: np.int64(22)
# | 52        | -20.0     | 51.64     | 1.325     | 50.61     | 1.816     | 2.441     | 0.3194    |
# | 53        | -20.0     | 50.64     | 1.626     | 51.18     | 1.241     | 51.63     | 1.638     |
# Error during simulation: np.int64(22)
# | 54        | -20.0     | 2.001     | 0.2128    | 51.45     | 0.03278   | 3.89      | 1.121     |
# Error during simulation: np.int64(22)
# | 55        | -20.0     | 51.78     | 1.876     | 2.193     | 0.7222    | 4.005     | 0.867     |
# Error during simulation: np.int64(22)
# | 56        | -20.0     | 4.679     | 1.337     | 2.107     | 1.984     | 51.65     | 0.1381    |
# Error during simulation: np.int64(22)
# | 57        | -20.0     | 2.553     | 0.6939    | 51.8      | 1.623     | 3.532     | 0.586     |
# | 58        | -20.0     | 51.13     | 1.168     | 51.91     | 0.186     | 51.61     | 0.8234    |
# Error during simulation: np.int64(22)
# | 59        | -20.0     | 51.81     | 1.315     | 3.273     | 0.006064  | 2.377     | 0.01025   |
# Error during simulation: np.int64(22)
# | 60        | -20.0     | 50.54     | 0.8558    | 2.059     | 0.1259    | 51.2      | 1.985     |
# Error during simulation: np.int64(22)
# | 61        | -20.0     | 3.132     | 1.179     | 3.448     | 0.1558    | 2.601     | 0.7793    |
# Error during simulation: np.int64(22)
# | 62        | -20.0     | 51.78     | 1.894     | 2.537     | 0.3711    | 51.95     | 0.8403    |
# Error during simulation: np.int64(22)
# | 63        | -20.0     | 51.36     | 1.783     | 2.155     | 0.7166    | 2.871     | 0.06567   |
# | 64        | -20.0     | 51.76     | 0.03957   | 50.99     | 0.8883    | 51.95     | 1.906     |
# Error during simulation: np.int64(22)
# | 65        | -20.0     | 2.724     | 0.6176    | 50.04     | 1.45      | 51.67     | 0.2754    |
# Error during simulation: np.int64(22)
# | 66        | -20.0     | 2.748     | 0.6812    | 51.26     | 1.779     | 3.39      | 1.247     |
# Error during simulation: np.int64(22)
# | 67        | -20.0     | 2.235     | 1.829     | 3.298     | 0.4489    | 50.45     | 0.4596    |
# | 68        | -20.0     | 51.63     | 1.145     | 51.95     | 1.162     | 3.965     | 1.758     |
# Error during simulation: np.int64(22)
# | 69        | -20.0     | 2.106     | 0.3725    | 51.05     | 1.864     | 4.433     | 0.7092    |
# | 70        | -20.0     | 2.368     | 1.992     | 2.16      | 1.879     | 51.75     | 1.015     |
# | 71        | -20.0     | 2.492     | 1.3       | 51.61     | 1.947     | 2.393     | 1.34      |
# | 72        | -20.0     | 51.1      | 1.221     | 51.31     | 0.2872    | 51.32     | 0.2503    |
# | 73        | -20.0     | 49.34     | 1.414     | 3.351     | 1.363     | 2.287     | 1.99      |
# Error during simulation: np.int64(22)
# | 74        | -20.0     | 50.33     | 1.656     | 2.4       | 0.4265    | 2.076     | 0.9794    |
# Error during simulation: np.int64(22)
# | 75        | -20.0     | 3.648     | 0.2773    | 2.469     | 1.775     | 2.289     | 1.924     |
# Error during simulation: np.int64(22)
# | 76        | -20.0     | 49.68     | 0.8614    | 50.64     | 1.686     | 51.98     | 0.004448  |
# Error during simulation: np.int64(22)
# | 77        | -20.0     | 2.827     | 0.423     | 51.29     | 1.721     | 50.84     | 0.151     |
# Error during simulation: np.int64(22)
# | 78        | -20.0     | 51.91     | 1.549     | 2.212     | 0.6579    | 50.35     | 1.303     |
# Error during simulation: np.int64(22)
# | 79        | -20.0     | 51.99     | 0.5935    | 51.12     | 1.222     | 3.699     | 1.091     |
# Error during simulation: np.int64(22)
# | 80        | -20.0     | 2.165     | 1.544     | 3.522     | 0.484     | 51.37     | 1.804     |
# | 81        | -20.0     | 51.48     | 0.3255    | 51.8      | 1.609     | 51.8      | 0.08707   |
# Error during simulation: np.int64(22)
# | 82        | -20.0     | 3.138     | 0.8411    | 2.638     | 1.659     | 2.503     | 0.7996    |
# | 83        | -20.0     | 3.518     | 0.2218    | 2.448     | 0.2892    | 2.465     | 1.687     |
# Error during simulation: np.int64(22)
# | 84        | -20.0     | 3.51      | 1.135     | 50.66     | 0.9566    | 2.688     | 1.852     |
# Error during simulation: np.int64(22)
# | 85        | -20.0     | 2.679     | 1.808     | 51.68     | 0.2835    | 2.413     | 1.842     |
# Error during simulation: np.int64(22)
# | 86        | -20.0     | 2.093     | 1.251     | 50.49     | 0.7217    | 51.77     | 0.6497    |
# Error during simulation: np.int64(22)
# | 87        | -20.0     | 51.1      | 0.2059    | 2.527     | 1.337     | 3.365     | 1.375     |
# Error during simulation: np.int64(22)
# | 88        | -20.0     | 2.765     | 0.3777    | 2.574     | 1.212     | 50.83     | 0.7859    |
# | 89        | -20.0     | 51.33     | 1.058     | 51.86     | 1.418     | 3.256     | 0.5306    |
# Error during simulation: np.int64(22)
# | 90        | -20.0     | 51.35     | 1.881     | 2.962     | 1.466     | 50.05     | 0.9106    |
# | 91        | -20.0     | 51.12     | 1.586     | 50.82     | 1.247     | 51.78     | 0.9776    |
# | 92        | -20.0     | 2.555     | 0.6419    | 51.73     | 0.2216    | 51.79     | 0.1629    |
# | 93        | -20.0     | 2.379     | 1.96      | 2.518     | 1.679     | 52.0      | 1.704     |
# Error during simulation: np.int64(22)
# | 94        | -20.0     | 50.29     | 0.05829   | 2.459     | 1.327     | 3.327     | 1.755     |
# | 95        | -20.0     | 50.73     | 0.4076    | 50.89     | 0.5958    | 2.064     | 0.7367    |
# | 96        | -20.0     | 2.186     | 0.04623   | 2.672     | 1.381     | 2.692     | 0.7438    |
# Error during simulation: np.int64(22)
# | 97        | -20.0     | 2.841     | 1.708     | 52.0      | 0.864     | 2.004     | 0.5563    |
# | 98        | -20.0     | 51.98     | 1.86      | 51.69     | 1.146     | 2.372     | 1.274     |
# Error during simulation: np.int64(22)
# | 99        | -20.0     | 51.34     | 1.637     | 51.62     | 0.7309    | 50.83     | 0.6853    |
# | 100       | -20.0     | 2.151     | 0.7616    | 2.543     | 0.4665    | 51.15     | 0.257     |
# | 101       | -20.0     | 2.702     | 1.174     | 51.9      | 1.962     | 51.44     | 1.271     |
# Error during simulation: np.int64(22)
# | 102       | -20.0     | 49.57     | 0.5649    | 2.138     | 0.9567    | 50.54     | 1.577     |
# | 103       | -20.0     | 2.905     | 0.3302    | 2.112     | 0.3971    | 2.646     | 0.8328    |
# Error during simulation: np.int64(22)
# | 104       | -20.0     | 51.79     | 1.007     | 3.024     | 1.067     | 2.912     | 0.9424    |
# Error during simulation: np.int64(22)
# | 105       | -20.0     | 50.59     | 1.597     | 2.028     | 0.9675    | 50.9      | 1.175     |
# | 106       | -20.0     | 51.98     | 1.441     | 51.78     | 1.544     | 51.48     | 1.45      |
# =================================================================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 optimiser = Optimisation(race_setup, overtake)
#       2 driver = 16
# ----> 3 best_strategy, best_position = optimiser.bayesian_strategy_optimization(given_driver=driver, max_iterations=100)
#       4 print(f"Best Strategy: {best_strategy}")
#       5 print(f"Best Finishing Position: {best_position}")
#
# File ~/Individual_Project/optimisation.py:154, in Optimisation.bayesian_strategy_optimization(self, given_driver, max_iterations)
#     152 # Evaluate the best strategy to get the finishing position
#     153 sim = RaceSimulation(self.race_data, self.overtake_model, given_driver=given_driver, simulated_strategy=best_strategy)
# --> 154 sim_data = sim.simulate()
#     155 sim_df = pd.DataFrame(sim_data)
#     156 best_position = sim_df[sim_df["driver_number"] == given_driver]["position"].iloc[-1]
#
# File ~/Individual_Project/race_sim.py:77, in RaceSimulation.simulate(self)
#      73 """
#      74 Simulate the race and return the final drivers' data.
#      75 """
#      76 for lap in range(1, self.race_data.max_laps + 1):
# ---> 77 	self._process_lap(lap)
#      79 return self.sim_data
#
# File ~/Individual_Project/race_sim.py:98, in RaceSimulation._process_lap(self, lap)
#      96 # Process each sector
#      97 for sector in range(1, 4):
# ---> 98 	self._process_sector(sector, lap, safety_car)
#
# File ~/Individual_Project/race_sim.py:154, in RaceSimulation._process_sector(self, sector, lap, safety_car)
#     152 if sector == 1 and lap in d["pit_schedule"]:
#     153 	d["pit"] = True
# --> 154 	d["cumulative_time"] += self.race_data.driver_pit_times[d["driver_number"]]
#     155 	d["stint_lap"] = 1
#     156 	d["tyre_type"] = d["pit_schedule"][lap]
#
# KeyError: np.int64(22)
