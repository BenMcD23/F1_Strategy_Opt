# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from database_operations import DatabaseOperations
from overtake_model import OvertakingModel
from race_data import RaceDataSetup
from race_dataframe import RaceDataframe
from race_sim import RaceSimulation
from evaluation import RaceSimEvaluation, EvaluateMany

# %%
db1 = DatabaseOperations(2024, "Sakhir")
race1 = RaceDataframe(db1)
race_data1 = RaceDataSetup(db1, race1)
overtake1 = OvertakingModel(race1.race_df)
test = overtake1.get_model_accuracy()[1]

# %%
print(test)
# Out:
#               precision    recall  f1-score   support
#
#  No Overtake       1.00      1.00      1.00      3296
#    Overtaken       0.85      0.85      0.85        91
#
#     accuracy                           0.99      3387
#    macro avg       0.92      0.92      0.92      3387
# weighted avg       0.99      0.99      0.99      3387

# %% [markdown]
# precision    recall  f1-score   support
#
#  No Overtake       0.99      1.00      1.00      3105
#    Overtaken       0.98      0.69      0.81        72
#
#     accuracy                           0.99      3177
#    macro avg       0.99      0.85      0.90      3177
# weighted avg       0.99      0.99      0.99      3177

# %%
# print(race_data1.driver_tyre_coefficients)

race_sim = RaceSimulation(race_data1, overtake1)
race_sim.simulate()
print(race_sim.num_overtakes)
sim_df = race_sim.get_results_as_dataframe()
sim_df
# Out:
# 195
#     driver_number       driver_name                 pit_schedule  tyre_type  \
# 0               1    Max Verstappen         {18: 3, 38: 1, 1: 1}          1
# 1              11      Sergio Perez         {13: 3, 37: 1, 1: 1}          1
# 2              55      Carlos Sainz         {15: 3, 36: 3, 1: 1}          3
# 3              16   Charles Leclerc         {12: 3, 35: 3, 1: 1}          3
# 4              44    Lewis Hamilton         {13: 3, 34: 3, 1: 1}          3
# 5              63    George Russell         {12: 3, 32: 3, 1: 1}          3
# 6               4      Lando Norris         {14: 3, 34: 3, 1: 1}          3
# 7              14   Fernando Alonso         {16: 3, 42: 3, 1: 1}          3
# 8              81     Oscar Piastri         {13: 3, 35: 3, 1: 1}          3
# 9               3  Daniel Ricciardo         {14: 3, 36: 1, 1: 1}          1
# 10             24       Guanyu Zhou         {10: 3, 29: 3, 1: 1}          3
# 11             18      Lance Stroll         {10: 3, 28: 3, 1: 1}          3
# 12             22      Yuki Tsunoda         {15: 3, 35: 3, 1: 1}          3
# 13             20   Kevin Magnussen         {12: 3, 33: 3, 1: 1}          3
# 14             23   Alexander Albon         {16: 3, 37: 3, 1: 1}          3
# 15             10      Pierre Gasly  {13: 3, 32: 3, 44: 1, 1: 1}          1
# 16             27   Nico Hulkenberg   {2: 3, 21: 3, 42: 1, 1: 1}          1
# 17             31      Esteban Ocon         {11: 3, 31: 3, 1: 1}          3
# 18             45    Logan Sargeant  {11: 3, 29: 3, 41: 1, 1: 1}          1
# 19             77   Valtteri Bottas         {13: 3, 31: 3, 1: 1}          3
#
# 15  {1: 29.148, 2: 38.857, 3: 22.829}          2                7
# 16  {1: 28.834, 2: 38.636, 3: 22.381}          0               -2
# 17  {1: 29.142, 2: 38.934, 3: 22.717}         -2              -11
# 18   {1: 28.991, 2: 39.119, 3: 22.66}          2               10
# 19  {1: 29.063, 2: 39.025, 3: 22.668}         -2              -10
#
#     drs_available  retired  predicted_overtake
# 0           False    False               False
# 1           False    False               False
# 2           False    False               False
# 3           False    False               False
# 4           False    False               False
# 5           False    False               False
# 6           False    False               False
# 7           False    False               False
# 8           False    False               False
# 9           False    False               False
# 10          False    False               False
# 11          False    False               False
# 12          False    False               False
# 13          False    False               False
# 14          False    False               False
# 15          False    False               False
# 16          False    False               False
# 17          False    False               False
# 18          False    False               False
# 19          False    False               False

# %%
eval = RaceSimEvaluation(race_sim, race1, db1)

print(eval.compare_total_cumulative_times()[1])
eval.compare_total_cumulative_times()[0]
# Out:
# 319.5020129760246
#     driver_number       driver_name  simulated_cumulative_time  \
# 0               1    Max Verstappen                5739.830037
# 1              11      Sergio Perez                5746.260959
# 2              55      Carlos Sainz                5764.303821
# 3              16   Charles Leclerc                5772.832058
# 4              44    Lewis Hamilton                5784.078161
# 5              63    George Russell                5784.375025
# 6               4      Lando Norris                5791.691374
# 7              14   Fernando Alonso                5805.185029
# 8              81     Oscar Piastri                5806.567906
# 9               3  Daniel Ricciardo                5819.260525
# 10             24       Guanyu Zhou                5821.211345
# 11             18      Lance Stroll                5823.647499
# 12             22      Yuki Tsunoda                5833.182573
# 13             20   Kevin Magnussen                5833.986945
# 14             23   Alexander Albon                5835.334076
# 15             10      Pierre Gasly                5849.986489
# 16             27   Nico Hulkenberg                5857.230895
# 17             31      Esteban Ocon                5858.925203
# 18             45    Logan Sargeant                5866.061232
# 19             77   Valtteri Bottas                5949.177107
#
#     actual_cumulative_time  absolute_error
# 0                 5472.340      267.490037
# 1                 5493.612      252.648959
# 2                 5495.858      268.445821
# 3                 5511.324      261.508058
# 4                 5519.946      264.132161
# 5                 5518.095      266.280025
# 6                 5518.585      273.106374
# 7                 5545.380      259.805029
# 8                 5526.014      280.553906
# 9                 5475.642      343.618525
# 10                5474.570      346.641345
# 11                5556.481      267.166499
# 12                5478.926      354.256573
# 13                5477.296      356.690945
# 14                5481.125      354.209076
# 15                5498.016      351.970489
# 16                5482.130      375.100895
# 17                5497.340      361.585203
# 18                5486.956      379.105232
# 19                5443.452      505.725107

# %%
eval.get_position_accuracy_final_class()
# Out:
# {'position_accuracy': 0.3,
#  'top_3_accuracy': 1.0,
#  'mean_error': 1.0,
#  'total_error': 20}

# %%
eval.compare_total_to_front()
# Out:
# {'total_simulated_gap_to_front': 1546.527516613426,
#  'total_actual_gap_to_front': 506.28799999999774}
