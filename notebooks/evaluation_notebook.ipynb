# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from database_operations import DatabaseOperations
from overtake_model import OvertakingModel
from race_data import RaceDataSetup
from race_dataframe import RaceDataframe
from race_sim import RaceSimulator
from evaluation import RaceSimEvaluation, EvaluateMany

import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
db1 = DatabaseOperations(2024, "Mexico City")
race1 = RaceDataframe(db1)
race_data1 = RaceDataSetup(db1, race1)
overtake1 = OvertakingModel(race1.race_df)
accuracy = overtake1.get_model_accuracy()[1]

# %%
# print(race_data1.driver_tyre_coefficients)

race_sim = RaceSimulator(race_data1, overtake1)
race_sim.simulate()
print(race_sim.num_overtakes)
sim_df = race_sim.get_results_as_dataframe()
sim_df
# Out:
# 84
#     driver_number       driver_name                 pit_schedule  tyre_type  \
# 0              55      Carlos Sainz                {33: 3, 1: 2}          3
# 1               4      Lando Norris                {31: 3, 1: 2}          3
# 2              16   Charles Leclerc         {32: 3, 70: 1, 1: 2}          1
# 3              44    Lewis Hamilton                {29: 3, 1: 2}          3
# 4              81     Oscar Piastri                {40: 3, 1: 2}          3
# 5              63    George Russell                {32: 3, 1: 2}          3
# 6               1    Max Verstappen                {27: 3, 1: 2}          3
# 7              20   Kevin Magnussen                {31: 3, 1: 2}          3
# 8              27   Nico Hulkenberg                {30: 3, 1: 2}          3
# 9              10      Pierre Gasly                {29: 3, 1: 2}          3
# 10             18      Lance Stroll                {27: 3, 1: 2}          3
# 11             45  Franco Colapinto                {48: 2, 1: 3}          2
# 12             31      Esteban Ocon                {1: 3, 49: 2}          2
# 13             77   Valtteri Bottas                {50: 2, 1: 3}          2
# 14             24       Guanyu Zhou                {44: 2, 1: 3}          2
# 15             40       Liam Lawson         {40: 2, 66: 1, 1: 3}          1
# 16             11      Sergio Perez  {21: 2, 44: 2, 69: 1, 1: 3}          1
# 17             23   Alexander Albon                       {1: 2}          2
# 18             22      Yuki Tsunoda                       {1: 2}          2
# 19             14   Fernando Alonso                       {1: 2}          2
#
#     lap_num  sector  sector_time   lap_time  stint_lap  cumulative_time  \
# 0        71       3    20.659784  80.490518         39      6263.274114
# 1        71       3    20.703931  80.138410         41      6265.449308
# 2        71       3    22.274851  80.832368          2      6288.469647
# 3        71       3    20.863479  80.851488         43      6299.578047
# 4        71       3    20.743427  80.656684         32      6310.674003
# 5        71       3    20.987247  81.584140         40      6311.681661
# 6        71       3    20.817306  81.291704         45      6317.422278
# 7        71       3    21.040058  81.192190         41      6327.308067
# 8        71       3    20.856500  81.326248         42      6343.899743
# 9        71       3    21.015713  81.706027         43      6363.300474
# 10       71       3    20.813931  81.588826         45      6369.164909
# 11       71       3    21.133117  81.876763         24      6369.504041
# 12       71       3    21.052458  81.505193         23      6371.008173
# 13       71       3    21.274378  82.532325         22      6390.646420
# 14       71       3    21.132451  81.941936         28      6390.795134
# 15       71       3    22.196024  84.396718          6      6392.904418
# 16       71       3    22.394419   0.000000          3      6248.430825
# 17       71       0     0.000000   0.000000         71         0.000000
# 18       71       0     0.000000   0.000000         71         0.000000
# 19       71       3    23.298221   0.000000         71      1495.102914
#
#           gap    pit       pace  position  starting_pos  \
# 0    0.000000  False  31.549575         1             1
# 1    2.175194  False  20.770952         2             2
# 2   23.020339  False  21.660755         3             3
# 3   11.108400  False  20.932355         4             4
# 4   11.095956  False  20.795339         5             8
# 5    1.007658  False  21.022026         6             5
# 6    5.740616  False  20.890183         7             6
# 7    9.885789  False  21.082077         8             7
# 8   16.591676  False  20.935128         9             9
# 9   19.400731  False  21.082269        10            10
# 10   5.864434  False  20.893399        11            11
# 11   0.339132  False  21.168223        12            12
# 12   1.504133  False  21.090353        13            13
# 13  19.638247  False  21.222762        14            14
# 14   0.148714  False  21.175391        15            15
# 15   2.109285  False  21.273599        16            16
# 16  21.601234  False  21.625742        17            17
# 17   0.000000  False   0.000000       998            19
# 18   0.000000  False   0.000000       998            20
# 19   0.131762  False  23.275269       999            18
#
#                     base_sector_times  tyre_diff  stint_laps_diff  \
# 0   {1: 27.037, 2: 29.296, 3: 19.533}          0                1
# 1    {1: 27.204, 2: 29.191, 3: 19.67}          0               -2
# 2   {1: 27.069, 2: 29.429, 3: 19.693}          2               39
# 3   {1: 27.295, 2: 29.546, 3: 19.688}         -2              -41
# 4   {1: 27.376, 2: 29.546, 3: 20.006}          0               11
# 5   {1: 27.361, 2: 29.263, 3: 19.624}          0               -8
# 6   {1: 27.222, 2: 29.318, 3: 19.631}          0               -5
# 7   {1: 27.272, 2: 29.624, 3: 19.854}          0                4
# 8   {1: 27.382, 2: 29.592, 3: 19.841}          0               -1
# 9   {1: 27.418, 2: 29.585, 3: 19.847}          0               -1
# 10  {1: 27.504, 2: 29.848, 3: 19.873}          0               -2
# 11  {1: 27.769, 2: 29.832, 3: 19.936}          1               21
# 12  {1: 27.658, 2: 29.887, 3: 20.072}          0                1
# 13  {1: 27.697, 2: 29.811, 3: 19.885}          0                1
# 14  {1: 27.746, 2: 30.217, 3: 20.109}          0               -6
# 15   {1: 27.636, 2: 29.64, 3: 19.833}          1               22
# 16  {1: 27.555, 2: 29.859, 3: 20.124}          1               25
# 17   {1: 27.344, 2: 29.58, 3: 19.855}          0                0
# 18    {1: 27.446, 2: 29.758, 3: 19.7}          0                0
# 19  {1: 27.463, 2: 29.665, 3: 19.898}          1                0
#
#     drs_available  active  laps_lapped predicted_overtake
# 0           False    True          0.0              False
# 1           False    True          0.0              False
# 2           False    True          0.0              False
# 3           False    True          0.0              False
# 4           False    True          0.0              False
# 5           False    True          0.0              False
# 6           False    True          0.0              False
# 7           False    True          0.0              False
# 8           False    True          0.0              False
# 9           False    True          0.0              False
# 10          False    True          0.0              False
# 11           True    True          0.0              False
# 12          False    True          0.0              False
# 13          False    True          0.0              False
# 14           True    True          0.0              False
# 15          False    True          0.0              False
# 16          False   False          1.0              False
# 17          False   False          0.0                NaN
# 18          False   False          0.0                NaN
# 19           True   False          0.0              False
