# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../")))

from database_operations import DatabaseOperations
from overtake_model import OvertakingModel
from race_data import RaceDataSetup
from race_dataframe import RaceDataframe
from race_sim import RaceSimulator
from evaluation import RaceSimEvaluation, EvaluateMany

import pandas as pd
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# %%
db1 = DatabaseOperations(2024, "Mexico City")
race1 = RaceDataframe(db1)
race_data1 = RaceDataSetup(db1, race1)
overtake1 = OvertakingModel(race1.race_df)
test = overtake1.get_model_accuracy()[1]

# %%
# race1.race_df[race1.race_df["lap_num"]>69]

# %%
# print(race_data1.driver_tyre_coefficients)

race_sim = RaceSimulator(race_data1, overtake1)
race_sim.simulate()
print(race_sim.num_overtakes)
sim_df = race_sim.get_results_as_dataframe()
sim_df
# Out:
# 110
#     driver_number       driver_name                 pit_schedule  tyre_type  \
# 0              55      Carlos Sainz                {33: 3, 1: 2}          3
# 1               4      Lando Norris                {31: 3, 1: 2}          3
# 2              16   Charles Leclerc         {32: 3, 70: 1, 1: 2}          1
# 3              44    Lewis Hamilton                {29: 3, 1: 2}          3
# 4              81     Oscar Piastri                {40: 3, 1: 2}          3
# 5              63    George Russell                {32: 3, 1: 2}          3
# 6               1    Max Verstappen                {27: 3, 1: 2}          3
# 7              20   Kevin Magnussen                {31: 3, 1: 2}          3
# 8              27   Nico Hulkenberg                {30: 3, 1: 2}          3
# 9              10      Pierre Gasly                {29: 3, 1: 2}          3
# 10             18      Lance Stroll                {27: 3, 1: 2}          3
# 11             45  Franco Colapinto                {48: 2, 1: 3}          2
# 12             77   Valtteri Bottas                {50: 2, 1: 3}          2
# 13             31      Esteban Ocon                {1: 3, 49: 2}          2
# 14             40       Liam Lawson         {40: 2, 66: 1, 1: 3}          1
# 15             24       Guanyu Zhou                {44: 2, 1: 3}          2
# 16             11      Sergio Perez  {21: 2, 44: 2, 69: 1, 1: 3}          1
# 17             23   Alexander Albon                       {1: 2}          2
# 18             22      Yuki Tsunoda                       {1: 2}          2
# 19             14   Fernando Alonso                       {1: 2}          2
#
#     lap_num  sector  sector_time  stint_lap  cumulative_time        gap  \
# 0        71       3    20.680441         39      6265.592876   0.000000
# 1        71       3    20.724588         41      6272.289063   6.696187
# 2        71       3    22.295508          2      6289.265994  16.976931
# 3        71       3    20.884135         43      6304.153196  14.887202
# 4        71       3    20.764084         32      6305.661022   1.507826
# 5        71       3    21.007904         40      6310.120762   4.459740
# 6        71       3    20.837963         45      6316.340322   6.219560
# 7        71       3    21.060715         41      6332.998778  16.658456
# 8        71       3    20.877154         42      6337.139302   4.140524
# 9        71       3    21.036346         43      6363.696844  26.557542
# 10       71       3    20.834588         45      6366.830532   3.133688
# 11       71       3    21.153774         24      6367.012553   0.182021
# 12       71       3    21.295035         22      6372.196659   5.184106
# 13       71       3    21.073116         23      6385.517754  13.321095
# 14       71       3    22.216681          6      6390.851841   5.334087
# 15       71       3    21.153108         28      6404.929371  14.077530
# 16       71       3    21.501304          3      6416.820456  11.891086
# 17       71       0     0.000000         71         0.000000   0.000000
# 18       71       0     0.000000         71         0.000000   0.000000
# 19       71       3    23.318879         71      1493.686362   3.634246
#
#       pit       pace  position  starting_pos  \
# 0   False  20.820673         1             1
# 1   False  20.791609         2             2
# 2   False  21.681420         3             3
# 3   False  20.953012         4             4
# 4   False  20.815996         5             8
# 5   False  21.042683         6             5
# 6   False  20.910840         7             6
# 7   False  21.102734         8             7
# 8   False  20.955780         9             9
# 9   False  21.102913        10            10
# 10  False  20.914056        11            11
# 11  False  21.188880        12            12
# 12  False  21.243419        13            14
# 13  False  21.111011        14            13
# 14  False  21.294256        15            16
# 15  False  21.196049        16            15
# 16  False  21.740517        17            17
# 17  False   0.000000       998            19
# 18  False   0.000000       998            20
# 19  False  23.295926       999            18
#
#                     base_sector_times  tyre_diff  stint_laps_diff  \
# 0   {1: 27.037, 2: 29.296, 3: 19.533}          0                1
# 1    {1: 27.204, 2: 29.191, 3: 19.67}          0               -2
# 2   {1: 27.069, 2: 29.429, 3: 19.693}          2               39
# 3   {1: 27.295, 2: 29.546, 3: 19.688}         -2              -41
# 4   {1: 27.376, 2: 29.546, 3: 20.006}          0               11
# 5   {1: 27.361, 2: 29.263, 3: 19.624}          0               -8
# 6   {1: 27.222, 2: 29.318, 3: 19.631}          0               -5
# 7   {1: 27.272, 2: 29.624, 3: 19.854}          0                4
# 8   {1: 27.382, 2: 29.592, 3: 19.841}          0               -1
# 9   {1: 27.418, 2: 29.585, 3: 19.847}          0               -1
# 10  {1: 27.504, 2: 29.848, 3: 19.873}          0               -2
# 11  {1: 27.769, 2: 29.832, 3: 19.936}          1               21
# 12  {1: 27.697, 2: 29.811, 3: 19.885}          0                2
# 13  {1: 27.658, 2: 29.887, 3: 20.072}          0               -1
# 14   {1: 27.636, 2: 29.64, 3: 19.833}          1               17
# 15  {1: 27.746, 2: 30.217, 3: 20.109}         -1              -22
# 16  {1: 27.555, 2: 29.859, 3: 20.124}          1               25
# 17   {1: 27.344, 2: 29.58, 3: 19.855}          0                0
# 18    {1: 27.446, 2: 29.758, 3: 19.7}          0                0
# 19  {1: 27.463, 2: 29.665, 3: 19.898}          0                0
#
#     drs_available  retired predicted_overtake
# 0           False    False              False
# 1           False    False              False
# 2           False    False              False
# 3           False    False              False
# 4           False    False              False
# 5           False    False              False
# 6           False    False              False
# 7           False    False              False
# 8           False    False              False
# 9           False    False              False
# 10          False    False              False
# 11           True    False              False
# 12          False    False              False
# 13          False    False              False
# 14          False    False              False
# 15          False    False              False
# 16          False    False              False
# 17          False     True                NaN
# 18          False     True                NaN
# 19          False     True              False

# %%
eval = RaceSimEvaluation(race_sim, race1, db1)

print(eval.compare_total_cumulative_times()[1])
eval.compare_total_cumulative_times()[0]
# Out:
# 272.85903803580794
#     driver_number       driver_name  simulated_cumulative_time  \
# 0              55      Carlos Sainz                6265.592876
# 1               4      Lando Norris                6272.289063
# 2              16   Charles Leclerc                6289.265994
# 3              44    Lewis Hamilton                6304.153196
# 4              81     Oscar Piastri                6305.661022
# 5              63    George Russell                6310.120762
# 6               1    Max Verstappen                6316.340322
# 7              20   Kevin Magnussen                6332.998778
# 8              27   Nico Hulkenberg                6337.139302
# 9              10      Pierre Gasly                6363.696844
# 10             18      Lance Stroll                6366.830532
# 11             45  Franco Colapinto                6367.012553
# 12             77   Valtteri Bottas                6372.196659
# 13             31      Esteban Ocon                6385.517754
# 14             40       Liam Lawson                6390.851841
# 15             24       Guanyu Zhou                6404.929371
# 16             11      Sergio Perez                6416.820456
# 17             23   Alexander Albon                   0.000000
# 18             22      Yuki Tsunoda                   0.000000
# 19             14   Fernando Alonso                1493.686362
#
#     actual_cumulative_time  absolute_error
# 0                 6023.912      241.680876
# 1                 6028.139      244.150063
# 2                 6057.475      231.790994
# 3                 6067.579      236.574196
# 4                 6083.971      221.690022
# 5                 6071.151      238.969762
# 6                 6083.463      232.877322
# 7                 6086.111      246.887778
# 8                 6024.711      312.428302
# 9                 5959.340      404.356844
# 10                6045.905      320.925532
# 11                6047.376      319.636553
# 12                6062.091      310.105659
# 13                6053.418      332.099754
# 14                6085.804      305.047841
# 15                6081.243      323.686371
# 16                6093.613      323.207456
# 17                     NaN             NaN
# 18                     NaN             NaN
# 19                1428.339       65.347362

# %%
eval.get_position_accuracy_final_class()
# Out:
# {'position_accuracy': 0.5294117647058824,
#  'top_3_accuracy': 1.0,
#  'mean_error': 0.5882352941176471,
#  'total_error': 10}

# %%
eval.compare_total_to_front()
# Out:
# {'total_simulated_gap_to_front': 1286.3384278794401,
#  'total_actual_gap_to_front': 1272.1519999999973}
